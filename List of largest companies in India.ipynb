# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/List_of_largest_companies_in_India#"

response = requests.get(url)
response
data = BeautifulSoup(response.content, "html.parser")

# %%
table = data.find_all('table')[0]
table_titles = table.find_all('th')
table_titles
india_table_titles = [titles.text.strip() for titles in table_titles]
print(india_table_titles)
# Out:
# ['Rank', 'Forbes 2000 rank', 'Name', 'Headquarters', 'Revenue(billions US$)', 'Profit(billions US$)', 'Assets(billions US$)', 'Value(billions US$)', 'Industry']

# %%
df= pd.DataFrame(columns = india_table_titles)

# %%
column_data = data.find_all('tr')

# %%
for row in column_data[1:72]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    print(individual_row_data)

    length = len(df)
    df.loc[length] = individual_row_data
# Out:
# ['1', '49', 'Reliance Industries Limited', 'Mumbai', '108.8', '8.4', '210.5', '233.1', 'Conglomerate']
# ['2', '55', 'State Bank of India', 'Mumbai', '71.8', '8.1', '807.4', '87.6', 'Banking']
# ['3', '65', 'HDFC Bank', 'Mumbai', '49.3', '7.7', '483.2', '133.6', 'Banking']
# ['4', '70', 'Life Insurance Corporation', 'New Delhi', '98.0', '4.9', '561.4', '73.6', 'Insurance']
# ['5', '142', 'ICICI Bank', 'Mumbai', '28.5', '5.3', '283.5', '95.3', 'Banking']
# ['6', '207', 'Oil and Natural Gas Corporation', 'New Delhi', '77.5', '5.1', '80.6', '41.9', 'Oil and gas']
# ['7', '259', 'Indian Oil Corporation', 'New Delhi', '93.8', '5.0', '57.8', '27.8', 'Oil and gas']
# ['8', '284', 'Tata Motors', 'Mumbai', '52.9', '3.8', '44.4', '43.8', 'Automotive']
# ['9', '293', 'Axis Bank', 'Mumbai', '16.7', '3.2', '182.0', '42.3', 'Banking']
# ['10', '372', 'NTPC Limited', 'New Delhi', '21.2', '2.4', '54.7', '42.5', 'Utilities']
# ...

# %%
df
# Out:
#    Rank Forbes 2000 rank                         Name Headquarters  \
# 0     1               49  Reliance Industries Limited       Mumbai
# 1     2               55          State Bank of India       Mumbai
# 2     3               65                    HDFC Bank       Mumbai
# 3     4               70   Life Insurance Corporation    New Delhi
# 4     5              142                   ICICI Bank       Mumbai
# ..  ...              ...                          ...          ...
# 66   65             1895     Dr. Reddy's Laboratories    Hyderabad
# 67   66             1908              Varun Beverages      Gurgaon
# 68   67             1949                        CIFCL      Chennai
# 69   68             1957                         NMDC    Hyderabad
# 70   69             1980                    ABB India    Bangalore
#
#    Revenue(billions US$) Profit(billions US$) Assets(billions US$)  \
# 0                  108.8                  8.4                210.5
# ...

# %%
df.to_csv(r'C:\Users\sande\movies project\List of largest companies in India.csv', index = False)
print("Data successfully saved to List of largest companies in India.csv")
# Out:
# Data successfully saved to List of largest companies in India.csv
